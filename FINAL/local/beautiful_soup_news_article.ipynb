# %%
# library installation
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
URL = "https://www.independent.com.mt/business"
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.text, 'html')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head id="ctl00_Head1">
#   <script data-blockingmode="auto" data-cbid="a8437fba-bf8d-4adb-b313-7a82eb48512e" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, user-scalable=yes, initial-scale=1, maximum-scale=3" name="viewport"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800" rel="stylesheet" type="text/css"/>
#   <link href="/css/design_styles.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/content_styles.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Business - The Malta Independent
#   </title>
#   <meta content="" name="Description"/>
#   <meta content="" name="Keywords"/>
#   <meta content="index,follow" name="Robots"/>
#   <meta content="Business - The Malta Independent " property="og:title"/>
#   <meta content="https://www.independent.com.mt/img/placeholdersmall.jpg" property="og:image"/>
#   <meta content="" property="og:description"/>
#   <meta content="httpss://www.independent.com.mt/business" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="709947179091415" property="fb:app_id"/>
#   <meta content="480288348662981" property="fb:pages"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@IndependentMlt" name="twitter:site"/>
#   <meta content="Business - The Malta Independent " name="twitter:title"/>
#   <meta content="" name="twitter:description"/>
#   <meta content="https://www.independent.com.mt/img/placeholdersmall.jpg" name="twitter:image"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="~/favicon.ico" rel="shortcut icon" title="The Malta Independent" type="image/ico"/>
#   <meta content="900" http-equiv="refresh"/>
#   <script src="/js/common_func.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function SendEmail(email1, email2, email3, subject) {
#         parent.location = 'mailto:' + email1 + '@' + email2 + '.' + email3 + '?subject=' + subject;
#     }
#
#     function FormatEmail(email1, email2, email3, subject) {
#         parent.location = email1 + '@' + email2 + '.' + email3;
#     }
#
# 	var advert1count;
# 	advert1count = 'true';
#   </script>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-BRG6LL4SKC">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-BRG6LL4SKC');
#   </script>
#   <!-- Alexa -->
#   <!-- Alexa-->
#   <!-- Start Alexa Certify Javascript -->
#   <script data-cookieconsent="statistics, marketing" type="text/plain">
#    _atrk_opts = { atrk_acct: "R75Ej1acJf00Mn", domain: "independent.com.mt", dynamic: true };
#         (function () { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=R75Ej1acJf00Mn" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Alexa Certify Javascript -->
#   <!-- Alexa -->
#   <!--[if lt IE 9]>
# 		<script src="js/html5shiv.js"></script>
# 	<![endif]-->
#   <!--[if IE 8 ]> <html class="ie8"> <![endif]-->
#   <!--<script src="/js/ThirdPartyJS/jquery-1.11.1.min.js"></script>
#     <script src="/js/ThirdPartyJS/jquery.lazyload.min.js"></script>-->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.lazyload/1.9.1/jquery.lazyload.min.js">
#   </script>
#   <title>
#   </title>
#  </head>
#  <body class="small-nav">
#   <form action="./business" id="aspnetForm" method="post" name="aspnetForm">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    <script type="text/javascript">
#     //<![CDATA[
# var UserLogedIn = 'False';//]]>
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="3989C74E"/>
#    <!-- login overlay -->
#    <style>
#     .LoginLoader-container {
#         display: none;
#     }
#
#         .LoginLoader-container .LoginLoader-Background {
#             position: absolute;
#             top: 0;
#             background-color: #d9d9d9;
#             -moz-opacity: 0.50;
#             -khtml-opacity: 0.50;
#             opacity: .5;
#             filter: progid:DXImageTransform.Microsoft.Alpha(opacity=50);
#             filter: alpha(opacity=50);
#             width: 100%;
#             height: 100%;
#             z-index: 998;
#         }
#
#         .LoginLoader-container img {
#             position: absolute;
#             z-index: 999;
#             top: 44%;
#             left: 45%;
#         }
#    </style>
#    <div class="overlay">
#     <script src="/bundles/logins.js?v=FmxPtGVnyepHx2A2wsRNsgGVCv1bi07aMN7QntBDXqE1">
#     </script>
#     <div class="wrapper">
#      <div class="login-container">
#       <div class="LoginLoader-container">
#        <div class="LoginLoader-Background">
#        </div>
#        <img src="../img/loader.gif"/>
#       </div>
#       <header class="login-head cfix">
#        <h3>
#         Login
#        </h3>
#        <a class="close-button">
#        </a>
#       </header>
#       <div class="login-section">
#        <ul>
#         <li>
#          <a class="login-fb" href="#">
#           Login with Facebook
#          </a>
#          <script type="text/javascript">
#           var AppId = '709947179091415';
#          </script>
#         </li>
#         <li>
#          <input id="ctl00_ctl04_GoogleLogin_hidUserAutoLogin" name="ctl00$ctl04$GoogleLogin$hidUserAutoLogin" type="hidden"/>
#          <a class="login-gplus" href="#">
#           Login with Google+
#          </a>
#          <script type="text/javascript">
#           var appClientId = '848547185251-s84l7r011us3uk4nfu8vrhs3um7bbdcn.apps.googleusercontent.com';
#     var apiKey = 'AIzaSyBTzCYgXtarjr1-DR2S3hB49xK1iMwUeaw';
#     var scopes = 'https://www.googleapis.com/auth/plus.login profile email https://www.googleapis.com/auth/plus.stream.write openid';
#     var cookiepolicy = 'single_host_origin';
#     var requestvisibleactions = 'https://schema.org/AddAction CommentAction';
#          </script>
#         </li>
#         <li>
#          <a class="login-twitter" href="#">
#           Login with Twitter
#          </a>
#         </li>
#         <li>
#          <a class="login-tmi">
#           Login with Independent
#          </a>
#         </li>
#        </ul>
#        <div>
#         <label>
#          <input id="socialKeepMeIn" type="checkbox"/>
#          Keep me signed in with social media
#         </label>
#        </div>
#       </div>
#       <div class="login-section">
#        <div class="tmi-login-container">
#         <input id="login_email" name="ctl00$ctl04$login_email" onblur="if(this.value == ''){ $(this).val('Your e-mail');}" onfocus="if(this.value == 'Your e-mail') { this.value = ''; }" type="text" value="Your e-mail">
#          <input id="login_password" name="ctl00$ctl04$login_password" onblur="if(this.value == ''){ $(this).prop('type','text').val('Your password');}" onfocus="if(this.value == 'Your password') { $(this).prop('type', 'password').val(''); }" type="text" value="Your password"/>
#          <label>
#           <input id="tmiRememberme" type="checkbox"/>
#           Remember me
#          </label>
#          <p class="error-message" id="login_error_message">
#          </p>
#          <span>
#           <input class="login-button" id="login-button" type="submit" value="Login"/>
#          </span>
#         </input>
#        </div>
#        <div class="popup-links">
#         <a class="popup-link" href="forgot-password">
#          Forgot your password?
#         </a>
#         <a class="popup-link" href="register-account">
#          Register
#         </a>
#        </div>
#       </div>
#       <span id="lblError">
#       </span>
#      </div>
#     </div>
#    </div>
#    <!-- end of login overlay -->
#    <div class="skyscraper-ad-container" id="ctl00_skyscraperAdvertContainer">
#     <!--style="left: 1451.5px;"-->
#     <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=45&amp;cb=93" frameborder="0" height="600" id="ab2eb8eb" name="ab2eb8eb" scrolling="no" width="120">
#      <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=af5b33be&amp;cb=93" target="_blank">
#       <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=45&amp;cb=93&amp;n=af5b33be"/>
#      </a>
#     </iframe>
#    </div>
#    <div class="skyscraper-ad-container-left" id="ctl00_skyscraperAdvertContainerLeft">
#     <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=119&amp;cb=297" frameborder="0" height="600" id="a9fec59d" name="a9fec59d" scrolling="no" width="120">
#      <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=a5d6fd8a&amp;cb=297" target="_blank">
#       <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=119&amp;cb=297&amp;n=a5d6fd8a"/>
#      </a>
#     </iframe>
#    </div>
#    <!-- header -->
#    <section class="top-panel">
#     <div class="wrapper">
#      <a class="logo-small" href="/">
#       <img alt="The Malta Independent" src="/img/logo-sm-new.png"/>
#      </a>
#      <span class="date">
#       4 March 2025, Tuesday
#      </span>
#      <ul class="weather">
#      </ul>
#      <a class="subscribe" href="/newsfeed" target="_blank">
#       RSS
#      </a>
#      <a class="epaper" href="https://maltaindependent.pressreader.com/" target="_blank">
#       View E-Paper
#      </a>
#      <div class="searchbar">
#       <div class="searchPanel" id="ctl00_Top1_Search_Panel1">
#        <input class="search defaultText" id="ctl00_Top1_Search_txtSearchField" name="ctl00$Top1$Search$txtSearchField" title="Search" type="text">
#         <br/>
#         <input id="ctl00_Top1_Search_btnSearch" name="ctl00$Top1$Search$btnSearch" onclick='javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions("ctl00$Top1$Search$btnSearch", "", true, "vgSearch", "", false, false))' type="submit" value="">
#         </input>
#        </input>
#       </div>
#      </div>
#     </div>
#    </section>
#    <div class="site-wrapper higher">
#     <div class="fixed-nav-wrapper">
#      <header class="wrapper">
#       <div class="head">
#        <div class="leaderboard-ad-container" id="ctl00_leaderboardAdvertContainer">
#         <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=116&amp;cb=238" frameborder="0" height="90" id="a8bec639" name="a8bec639" scrolling="no" width="728">
#          <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=a511b697&amp;cb=238" target="_blank">
#           <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=116&amp;cb=238&amp;n=a511b697"/>
#          </a>
#         </iframe>
#        </div>
#       </div>
#      </header>
#      <nav class="wrapper">
#       <a id="menu-button">
#       </a>
#       <ul class="menu">
#        <!-----  Template ---->
#        <!----- End of Template ---->
#        <li id="menu-item1">
#         <a class="menu-color1" href="/" target="_self">
#          <img src="/img/icon-home.png"/>
#         </a>
#         <ul class="" id="">
#         </ul>
#        </li>
#        <li id="menu-item2">
#         <a class="menu-color2" href="/local" target="_self">
#          Local
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/local-news" target="_self">
#            News
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/local-interviews" target="_self">
#            Interviews
#           </a>
#          </li>
#          <li>
#           <a class="" href="/mostread" target="_self">
#            Most Read
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item3">
#         <a class="menu-color3" href="/world" target="_self">
#          World
#         </a>
#         <ul class="" id="submenu3">
#          <li>
#           <a class="" href="/archive/world-news" target="_self">
#            News
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/world-oddities" target="_self">
#            Oddities
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item4">
#         <a class="menu-color4" href="/debate" target="_self">
#          Debate
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/editors-blog" target="_self">
#            Editor's Blog
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/blogs-opinions" target="_self">
#            Blogs &amp; Opinions
#           </a>
#          </li>
#          <li>
#           <a class="" href="/polls" target="_self">
#            Polls
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item5">
#         <a class="menu-color5" href="/sports" target="_self">
#          Sports
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/football" target="_self">
#            Football
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/tennis" target="_self">
#            Tennis
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/f1" target="_self">
#            MOTORSPORTS
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/waterpolo" target="_self">
#            Waterpolo
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/basketball" target="_self">
#            Basketball
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/olympics" target="_self">
#            Olympics
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/commonwealthgames" target="_self">
#            Commonwealth Games
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/sports-others" target="_self">
#            Others
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item6">
#         <a class="menu-color6" href="/business" target="_self">
#          Business
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/business-news" target="_self">
#            News
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/business-world" target="_self">
#            World
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/financial" target="_self">
#            Financial
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/company-news" target="_self">
#            Company News
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item7">
#         <a class="menu-color7 selected" href="/arts" target="_self">
#          Arts
#         </a>
#         <ul class="submenu-open" id="">
#          <li>
#           <a class="" href="/archive/stage" target="_self">
#            Stage
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/books" target="_self">
#            Books
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/music" target="_self">
#            Music
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/cinema" target="_self">
#            Cinema
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/tv" target="_self">
#            TV
#           </a>
#          </li>
#          <li>
#           <a class="" href="/crossword" target="_self">
#            Crossword
#           </a>
#          </li>
#          <li>
#           <a class="" href="/sudoku" target="_self">
#            Sudoku
#           </a>
#          </li>
#          <li>
#           <a class="" href="/arcade" target="_self">
#            Arcade
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item8">
#         <a class="menu-color8" href="/life" target="_self">
#          Life
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/human" target="_self">
#            Human
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/health" target="_self">
#            Health
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/food" target="_self">
#            Food
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/education" target="_self">
#            Education
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/growing-up" target="_self">
#            Growing Up
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/motoring" target="_self">
#            Motoring
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/fashion" target="_self">
#            Fashion
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item9">
#         <a class="menu-color9" href="/videos" target="_self">
#          Videos
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/videos" target="_self">
#            Latest Videos
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/indepth" target="_self">
#            Indepth
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item10">
#         <a class="menu-color10" href="/newspaper" target="_self">
#          Newspaper
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/newspaper-leader" target="_self">
#            Leader
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/newspaper-letters" target="_self">
#            Letters
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/newspaper-opinions" target="_self">
#            Opinions
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/newspaper-cartoon" target="_self">
#            Cartoon
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/newspaper-lifestyleculture" target="_self">
#            Lifestyle &amp; Culture
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-supplements" target="_self">
#            Supplements
#           </a>
#          </li>
#          <li>
#           <a class="" href="http://maltaindependent.pressreader.com/" target="_blank">
#            E-Paper
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item11">
#         <a class="menu-color11" href="/magazines" target="_self">
#          Magazines
#         </a>
#         <ul class="" id="">
#          <li>
#           <a class="" href="/archive/magazine-tasteflair" target="_self">
#            Taste &amp; Flair
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-first" target="_self">
#            First
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-AandH" target="_self">
#            A &amp; H
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-ido" target="_self">
#            I DO
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-motoring" target="_self">
#            Motoring
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-vamp" target="_self">
#            Vamp
#           </a>
#          </li>
#          <li>
#           <a class="" href="/archive/magazine-malta-business-review" target="_self">
#            Malta Business Review
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="menu-item12">
#         <a class="menu-color12" href="/jobsinmalta" target="_self">
#          Jobs In Malta
#         </a>
#         <ul class="" id="">
#         </ul>
#        </li>
#        <li id="mbw-link">
#         <a class="logo-wrapper" href="https://maltabusinessweekly.com/" style="border:none;" target="_blank">
#          <img src="../img/mbw.png"/>
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div class="wrapper articles-wrapper" id="ctl00_wrapperArticlesWrapper">
#      <!-- level 1 -->
#      <section class="level-1">
#       <div class="col-3">
#        <div class="col-2">
#         <ul class="breadcrumbs">
#          <li>
#           <a href="/">
#            Home
#           </a>
#          </li>
#          <li>
#           &gt;
#          </li>
#          <li>
#           Business
#          </li>
#         </ul>
#         <div class="entry-wrapper no-border">
#          <h2>
#           Business
#          </h2>
#          <div class="pagination-container">
#           <ul>
#            <li>
#             <a "="" class="disabled" href="">
#              First
#             </a>
#            </li>
#            <li>
#             <a "="" class="disabled" href="">
#              Prev
#             </a>
#            </li>
#            <li>
#             <a class="active" href="?pg=1">
#              1
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2">
#              2
#             </a>
#            </li>
#            <li>
#             <a href="?pg=3">
#              3
#             </a>
#            </li>
#            <li>
#             <a href="?pg=4">
#              4
#             </a>
#            </li>
#            <li>
#             <a href="?pg=5">
#              5
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2">
#              Next
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2824">
#              Last
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#            <img src="file.aspx?f=249081&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#            <h4>
#             Atlas Insurance and SOS Malta launch VR education initiative in Maltese schools
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 12:26
#            </span>
#            <span class="last-update">
#             Last update: about 49 seconds ago
#            </span>
#           </div>
#           <p>
#            Atlas Insurance and SOS Malta inaugurated their three-year initiative to integrate virtual reality (VR) technology into the curricula of two independent schools and one church school. This project...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#            <img src="file.aspx?f=249080&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#            <h4>
#             MDB hosts 20 European institutions to discuss the challenges of digital financing
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 12:21
#            </span>
#            <span class="last-update">
#             Last update: about 5 minutes ago
#            </span>
#           </div>
#           <p>
#            The Malta Development Bank (MDB), in collaboration with the European Association of Guarantee Institutions (AECM), hosted a high-level technical workshop on digital financing, bringing together 20...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#            <img src="file.aspx?f=249079&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#            <h4>
#             BOV encourages smarter money management with cash migration incentive
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 11:29
#            </span>
#            <span class="last-update">
#             Last update: about 57 minutes ago
#            </span>
#           </div>
#           <p>
#            Bank of Valletta is launching a Cash Migration Incentive as part of its commitment to financial literacy and responsible banking. This initiative, running from 1st March to 30th June 2025, aims to...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#            <img src="file.aspx?f=249075&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#            <h4>
#             Maltese Payroll Software Company Buddy kicks off Payroll Growth Summit today
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 09:21
#            </span>
#            <span class="last-update">
#             Last update: about 3 hours ago
#            </span>
#           </div>
#           <p>
#            Maltese technology leader Buddy is proud to announce the Payroll Growth Summit, a free, virtual event designed to equip payroll professionals with actionable insights in compliance, technology, and...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#            <img src="file.aspx?f=249073&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#            <h4>
#             HSBC Malta Foundation supports K-9 Urban Search and Rescue Malta
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 09:16
#            </span>
#            <span class="last-update">
#             Last update: about 3 hours ago
#            </span>
#           </div>
#           <p>
#            HSBC Malta Foundation is proud to support K-9 Urban Search and Rescue Malta (K-9 USAR Malta), a dedicated non-profit organisation committed to training highly specialised search and rescue dogs for...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#            <img src="file.aspx?f=249072&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#            <h4>
#             New shores beckon for Boston Multi Family Office on completion of acquisition of Aqua Group
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Tuesday, 4 March 2025, 09:15
#            </span>
#            <span class="last-update">
#             Last update: about 3 hours ago
#            </span>
#           </div>
#           <p>
#            Isle of Man-headquartered Boston Multi Family Office is pleased to announce the completion of its acquisition of Aqua Group, a leading family office and fiduciary business based in Jersey, Malta and...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#            <img src="file.aspx?f=249025&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#            <h4>
#             Trump economics: Inflation trends and pressures on European commerce
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Sunday, 2 March 2025, 08:00
#            </span>
#            <span class="last-update">
#             Last update: about 4 days ago
#            </span>
#            <span class="author">
#             George M Mangion
#            </span>
#           </div>
#           <p>
#            Following President Trump's election, many predict that inflation will remain a concern, particularly in service prices. The situation in the US economy is buoyant yet overall inflation in the...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#            <img src="file.aspx?f=249027&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#            <h4>
#             Fundación MAPFRE supports P.O.P – Up' project in collaboration with MFWS
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Friday, 28 February 2025, 14:15
#            </span>
#            <span class="last-update">
#             Last update: about 3 days ago
#            </span>
#           </div>
#           <p>
#            Fundación MAPFRE is proud to announce its support for the "Promoting Online Protection Project" (P.O.P - Up Project) in collaboration with The Malta Foundation for the Wellbeing of Society...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2025-02-27/business-news/Independent-research-recognises-Melita-as-a-leading-employer-in-Malta-6736268195">
#            <img src="file.aspx?f=248964&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2025-02-27/business-news/Independent-research-recognises-Melita-as-a-leading-employer-in-Malta-6736268195">
#            <h4>
#             Independent research recognises Melita as a leading employer in Malta
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Thursday, 27 February 2025, 13:56
#            </span>
#            <span class="last-update">
#             Last update: about 4 days ago
#            </span>
#           </div>
#           <p>
#            Independent Employee Survey conducted by HR systems provider Talexio has highlighted high levels of job satisfaction among Melita Limited employees, positioning the company as one of the best...
#           </p>
#          </div>
#         </article>
#         <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#          <div class="image-section">
#           <a href="articles/2024-10-02/business-news/Matrixyl-Peptide-Exploring-its-multifaceted-potential-in-scientific-research-6736264556">
#            <img src="file.aspx?f=245112&amp;width=480&amp;height=270"/>
#           </a>
#          </div>
#          <div class="snippet-container">
#           <a href="articles/2024-10-02/business-news/Matrixyl-Peptide-Exploring-its-multifaceted-potential-in-scientific-research-6736264556">
#            <h4>
#             Matrixyl Peptide: Exploring its multifaceted potential in scientific research
#            </h4>
#           </a>
#           <div class="info-container">
#            <span class="date-published">
#             Wednesday, 2 October 2024, 10:23
#            </span>
#            <span class="last-update">
#             Last update: about 6 months ago
#            </span>
#           </div>
#           <p>
#            Matrixyl, a synthetic peptide, has garnered significant interest in various scientific domains due to its potential impact on cellular processes related to extracellular matrix (ECM) modulation,...
#           </p>
#          </div>
#         </article>
#         <div class="entry-wrapper no-border">
#          <div class="pagination-container">
#           <ul>
#            <li>
#             <a "="" class="disabled" href="">
#              First
#             </a>
#            </li>
#            <li>
#             <a "="" class="disabled" href="">
#              Prev
#             </a>
#            </li>
#            <li>
#             <a class="active" href="?pg=1">
#              1
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2">
#              2
#             </a>
#            </li>
#            <li>
#             <a href="?pg=3">
#              3
#             </a>
#            </li>
#            <li>
#             <a href="?pg=4">
#              4
#             </a>
#            </li>
#            <li>
#             <a href="?pg=5">
#              5
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2">
#              Next
#             </a>
#            </li>
#            <li>
#             <a href="?pg=2824">
#              Last
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="col-1">
#         <div class="rectangle-ad-container">
#          <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=44&amp;cb=286" frameborder="0" height="250" id="a578e25f" name="a578e25f" scrolling="no" width="300">
#           <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=a592d092&amp;cb=286" target="_blank">
#            <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=44&amp;cb=286&amp;n=a592d092"/>
#           </a>
#          </iframe>
#         </div>
#         <div class="rectangle-ad-container">
#          <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=115&amp;cb=256" frameborder="0" height="250" id="a295273c" name="a295273c" scrolling="no" width="300">
#           <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=a5e989a8&amp;cb=256" target="_blank">
#            <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=115&amp;cb=256&amp;n=a5e989a8"/>
#           </a>
#          </iframe>
#         </div>
#         <script src="/js/dontMissItems.js">
#         </script>
#         <ul class="dont-miss">
#          <li class="list-header">
#           don't miss
#          </li>
#         </ul>
#         <div class="rectangle-ad-container">
#          <!--/* Revive Adserver iFrame Tag v3.0.5 */-->
#          <!--/*
#   * This tag has been generated for use on a non-SSL page. If this tag
#   * is to be placed on an SSL page, change the
#   *   'https://ads.independent.com.mt/www/delivery/...'
#   * to
#   *   'https://ads.independent.com.mt/www/delivery/...'
#   *
#   * The backup image section of this tag has been generated for use on a
#   * non-SSL page. If this tag is to be placed on an SSL page, change the
#   *   'https://ads.independent.com.mt/www/delivery/...'
#   * to
#   *   'https://ads.independent.com.mt/www/delivery/...'
#   *
#   * If iFrames are not supported by the viewer's browser, then this
#   * tag only shows image banners. There is no width or height in these
#   * banners, so if you want these tags to allocate space for the ad
#   * before it shows, you will need to add this information to the <img>
#   * tag.
#   */-->
#          <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=147&amp;cb=59" frameborder="0" height="250" id="a65e2a3a" name="a65e2a3a" scrolling="no" width="300">
#           <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=afda3e6e&amp;cb=59" target="_blank">
#            <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=147&amp;cb=59&amp;n=afda3e6e"/>
#           </a>
#          </iframe>
#         </div>
#         <div class="iframe-wrapper">
#          <div class="iframe-container jobs-container property-container" style="overflow-x: hidden;">
#           <iframe height="568" src="https://www.noagentfees.com/iframe" style="border: none;" width="300">
#           </iframe>
#          </div>
#         </div>
#         <div class="fb-like-box" data-colorscheme="light" data-header="true" data-height="215" data-href="https://www.facebook.com/TheMaltaIndependent" data-show-border="true" data-show-faces="true" data-stream="false" data-width="300">
#         </div>
#        </div>
#       </div>
#       <div class="col-3 horizontal-floor">
#        <div class="leaderboard-ad-container" id="ctl00_leaderboardAdvertContainerbottom">
#         <iframe class="tmiads" data-src="https://ads.independent.com.mt/www/delivery/afr.php?zoneid=43&amp;cb=269" frameborder="0" height="90" id="af1935e1" name="af1935e1" scrolling="no" width="728">
#          <a href="https://ads.independent.com.mt/www/delivery/ck.php?n=af479980&amp;cb=269" target="_blank">
#           <img alt="" border="0" data-src="https://ads.independent.com.mt/www/delivery/avw.php?zoneid=43&amp;cb=269&amp;n=af479980"/>
#          </a>
#         </iframe>
#         <!--<script id="Cookiebot" src="https://consent.cookiebot.com/uc.js" data-cbid="a8437fba-bf8d-4adb-b313-7a82eb48512e" data-blockingmode="auto" type="text/javascript"></script>-->
#        </div>
#        <section class="carousel cfix">
#         <div class="carousel-wrapper">
#          <span class="ar-left">
#          </span>
#          <div class="carousel-center">
#           <div class="carousel-title">
#            <a href="/business">
#             Business
#            </a>
#           </div>
#           <div class="carousel-content-gallery">
#            <div class="carousel-content-container">
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl00_imgThumbnail" src="file.aspx?f=249081&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 Atlas Insurance and SOS Malta launch VR…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl01_imgThumbnail" src="file.aspx?f=249080&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 MDB hosts 20 European institutions to…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl02_imgThumbnail" src="file.aspx?f=249079&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 BOV encourages smarter money management…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl03_imgThumbnail" src="file.aspx?f=249075&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 Maltese Payroll Software Company Buddy…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#               <div class="item-image-container">
#                <img alt="Representatives of the K-9 USAR Malta, a dedicated non-profit organisation committed to training highly specialised search and rescue dogs for disaster response" border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl04_imgThumbnail" src="file.aspx?f=249073&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 HSBC Malta Foundation supports K-9…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#               <div class="item-image-container">
#                <img alt="From left: Alex McNee, Sarah Mullins, Jo Luce" border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl05_imgThumbnail" src="file.aspx?f=249072&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 New shores beckon for Boston Multi…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl06_imgThumbnail" src="file.aspx?f=249025&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 Trump economics: Inflation trends and…
#                </p>
#               </div>
#              </a>
#             </article>
#             <article class="carousel-item">
#              <a href="/articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#               <div class="item-image-container">
#                <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl07_imgThumbnail" src="file.aspx?f=249027&amp;width=160&amp;height=145"/>
#               </div>
#               <div class="item-title-container">
#                <p>
#                 Fundación MAPFRE supports P.O.P – Up'…
#                </p>
#               </div>
#              </a>
#             </article>
#            </div>
#           </div>
#          </div>
#          <span class="ar-right">
#          </span>
#         </div>
#        </section>
#       </div>
#      </section>
#     </div>
#    </div>
#    <!-- footer -->
#    <footer class="fixed-footer open">
#     <div class="wrapper">
#      <a class="footer-button">
#       open
#      </a>
#     </div>
#     <div class="main-footer-container">
#      <div class="wrapper cfix">
#       <ul>
#        <li>
#         <a href="/terms-of-use">
#          Terms of Use
#         </a>
#        </li>
#        <li>
#         <a href="/advertising-rates">
#          Advertising Rates
#         </a>
#        </li>
#        <li>
#         <a href="/contactus">
#          Contact Us
#         </a>
#        </li>
#        <li>
#         <a href="/privacy-policy">
#          Privacy Policy
#         </a>
#        </li>
#        <li>
#         <a href="cookie-declaration">
#          Cookie Declaration
#         </a>
#        </li>
#       </ul>
#       <span class="credits">
#        Designed and developed by
#        <a href="https://www.deloittedigital.com.mt/" target="_blank">
#         Deloitte Digital
#        </a>
#       </span>
#       <div class="copy">
#        <p>
#         Independent Online. ©2025. Standard Publications Ltd. Registered Office: Standard House, Birkirkara Hill, St. Julian’s, STJ 1149, Malta.
#        </p>
#       </div>
#      </div>
#     </div>
#    </footer>
#    <script src="/bundles/jquery.js?v=yguHXKfLvQ2zUEUBJQ9y2OFvr0MhXiNLCbdwN7iffoY1">
#    </script>
#    <script src="/bundles/mustache.js?v=GFDof1wXEILpdC4KsZEXv_uACRCzctjPLNTi2pgoi-01">
#    </script>
#    <script src="/bundles/other.js?v=OQKUeICx2j9M2roC8H8Ce-jxmm8hxB-3uqEzSJQmSpk1">
#    </script>
#    <!-- Facebook Widget -->
#    <div id="fb-root">
#    </div>
#    <script>
#     (function (d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_EN/sdk.js#xfbml=1&version=v2.0";
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));
#    </script>
#    <!-- end of Facebook widget -->
#    <!--<script type="text/javascript" src="https://s7.addthis.com/js/300/addthis_widget.js#pubid=ra-542e4c8a18adc455"></script>-->
#    <script data-cookieconsent="marketing" src="https://s7.addthis.com/js/300/addthis_widget.js#pubid=ra-542e4c8a18adc455" type="text/plain">
#    </script>
#    <!--<script type="text/javascript">-->
#    <script data-cookieconsent="marketing" type="text/plain">
#     $(document).ready(function () {
#
#         setTimeout(function() {
#
#             addthis.layers({
#                 'theme': 'transparent',
#                 'share': {
#                     'position': 'left',
#                     'numPreferredServices': 5
#                 },
# 				'recommended': {
# 					'mobile': true,
# 					'desktop': true,
# 				},
#                 'follow': {
#                     'services': [
#                         { 'service': 'facebook', 'id': 'TheMaltaIndependent' },
#                         { 'service': 'twitter', 'id': 'IndependentMlt' },
#                         { 'service': 'google_follow', 'id': '+TheMaltaIndependent' },
#                         { 'service': 'youtube', 'id': 'MaltaIndependent' }
#                     ]
#                 },
#                 'whatsnext': {},
#                 'linkFilter': function (link, layer) {
#                     if (link.url && (link.url.indexOf('https://www.independent.com.mt/articles/2025-3-04') >= 0) || (link.url.indexOf('https://www.independent.com.mt/articles/2025-3-3') >= 0) || (link.url.indexOf('https://www.independent.com.mt/articles/2025-3-2') >= 0)) {
#                         return link;
#                     } else {
#                         return false;
#                     }
#                 },
#                 'thankyou': false
#             });
#
#         }, 2000);
#
#     });
#
#     function RebindAddThis() {
#         addthis.button(".addthis_button");
#     };
#    </script>
#    <!-- AddThis Smart Layers END -->
#    <!-- AddThis Button BEGIN -->
#    <script type="text/javascript">
#     var addthis_config = { "data_track_addressbar": false };
#    </script>
#    <!-- AddThis Button END -->
#    <!--Google Analytics-->
#    <script data-cookieconsent="statistics" type="text/plain">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-23304770-14', 'auto');
#   ga('send', 'pageview');
#    </script>
#    <!-- advertising -->
#    <script data-cfasync="false" data-cookieconsent="statistics, marketing" id="clevernt" type="text/plain">
#     (function (document, window) {
#             var c = document.createElement("script");
#             c.type = "text/javascript";
#             c.async = !0;
#             c.src = "//clevernt.com/scripts/1c7d4cbbcf3bc6e5bdc031e0c6b598c6.min.js?20180427=" + Math.floor((new Date).getTime());
#             var a = !1;
#             try {
#                 a = parent.document.getElementsByTagName("script")[0] || document.getElementsByTagName("script")[0];
#             } catch (e) {
#                 a = !1;
#             }
#             a || (a = document.getElementsByTagName("head")[0] || document.getElementsByTagName("body")[0]);
#             a.parentNode.insertBefore(c, a);
#         })(document, window);
#    </script>
#    <!-- end advertising -->
#   </form>
#   <script>
#    (function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'91b0fff88ba3edb0',t:'MTc0MTA4NzM5MC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();
#   </script>
#  </body>
# </html>

# %%
business_article = soup.find_all('article')
business_article
# Out:
# [<article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#  <img src="file.aspx?f=249081&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#  <h4>Atlas Insurance and SOS Malta launch VR education initiative in Maltese schools </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 12:26</span>
#  <span class="last-update">Last update: about 49 seconds ago</span>
#  </div>
#  <p>Atlas Insurance and SOS Malta inaugurated their three-year initiative to integrate virtual reality (VR) technology into the curricula of two independent schools and one church school. This project... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#  <img src="file.aspx?f=249080&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#  <h4>MDB hosts 20 European institutions to discuss the challenges of digital financing </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 12:21</span>
#  <span class="last-update">Last update: about 5 minutes ago</span>
#  </div>
#  <p>The Malta Development Bank (MDB), in collaboration with the European Association of Guarantee Institutions (AECM), hosted a high-level technical workshop on digital financing, bringing together 20... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#  <img src="file.aspx?f=249079&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#  <h4>BOV encourages smarter money management with cash migration incentive </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 11:29</span>
#  <span class="last-update">Last update: about 57 minutes ago</span>
#  </div>
#  <p>Bank of Valletta is launching a Cash Migration Incentive as part of its commitment to financial literacy and responsible banking. This initiative, running from 1st March to 30th June 2025, aims to... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#  <img src="file.aspx?f=249075&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#  <h4>Maltese Payroll Software Company Buddy kicks off Payroll Growth Summit today  </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 09:21</span>
#  <span class="last-update">Last update: about 3 hours ago</span>
#  </div>
#  <p>Maltese technology leader Buddy is proud to announce the Payroll Growth Summit, a free, virtual event designed to equip payroll professionals with actionable insights in compliance, technology, and... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#  <img src="file.aspx?f=249073&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#  <h4>HSBC Malta Foundation supports K-9 Urban Search and Rescue Malta </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 09:16</span>
#  <span class="last-update">Last update: about 3 hours ago</span>
#  </div>
#  <p>HSBC Malta Foundation is proud to support K-9 Urban Search and Rescue Malta (K-9 USAR Malta), a dedicated non-profit organisation committed to training highly specialised search and rescue dogs for... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#  <img src="file.aspx?f=249072&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#  <h4>New shores beckon for Boston Multi Family Office on completion of acquisition of Aqua Group  </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Tuesday, 4 March 2025, 09:15</span>
#  <span class="last-update">Last update: about 3 hours ago</span>
#  </div>
#  <p>Isle of Man-headquartered Boston Multi Family Office is pleased to announce the completion of its acquisition of Aqua Group, a leading family office and fiduciary business based in Jersey, Malta and... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#  <img src="file.aspx?f=249025&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#  <h4>Trump economics: Inflation trends and pressures on European commerce  </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Sunday, 2 March 2025, 08:00</span>
#  <span class="last-update">Last update: about 4 days ago</span>
#  <span class="author">George M Mangion</span>
#  </div>
#  <p>Following President Trump's election, many predict that inflation will remain a concern, particularly in service prices. The situation in the US economy is buoyant yet overall inflation in the... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#  <img src="file.aspx?f=249027&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#  <h4>Fundación MAPFRE supports P.O.P – Up' project in collaboration with MFWS </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Friday, 28 February 2025, 14:15</span>
#  <span class="last-update">Last update: about 3 days ago</span>
#  </div>
#  <p>Fundación MAPFRE is proud to announce its support for the "Promoting Online Protection Project" (P.O.P - Up Project) in collaboration with The Malta Foundation for the Wellbeing of Society... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2025-02-27/business-news/Independent-research-recognises-Melita-as-a-leading-employer-in-Malta-6736268195">
#  <img src="file.aspx?f=248964&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2025-02-27/business-news/Independent-research-recognises-Melita-as-a-leading-employer-in-Malta-6736268195">
#  <h4>Independent research recognises Melita as a leading employer in Malta </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Thursday, 27 February 2025, 13:56</span>
#  <span class="last-update">Last update: about 4 days ago</span>
#  </div>
#  <p>Independent Employee Survey conducted by HR systems provider Talexio has highlighted high levels of job satisfaction among Melita Limited employees, positioning the company as one of the best... </p>
#  </div>
#  </article>,
#  <article calculateheight="true" class="entry-wrapper category-entry-wrapper no-border">
#  <div class="image-section">
#  <a href="articles/2024-10-02/business-news/Matrixyl-Peptide-Exploring-its-multifaceted-potential-in-scientific-research-6736264556">
#  <img src="file.aspx?f=245112&amp;width=480&amp;height=270"/></a>
#  </div>
#  <div class="snippet-container">
#  <a href="articles/2024-10-02/business-news/Matrixyl-Peptide-Exploring-its-multifaceted-potential-in-scientific-research-6736264556">
#  <h4>Matrixyl Peptide: Exploring its multifaceted potential in scientific research </h4>
#  </a>
#  <div class="info-container">
#  <span class="date-published">Wednesday, 2 October 2024, 10:23</span>
#  <span class="last-update">Last update: about 6 months ago</span>
#  </div>
#  <p>Matrixyl, a synthetic peptide, has garnered significant interest in various scientific domains due to its potential impact on cellular processes related to extracellular matrix (ECM) modulation,... </p>
#  </div>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/Atlas-Insurance-and-SOS-Malta-launch-VR-education-initiative-in-Maltese-schools-6736268317">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl00_imgThumbnail" src="file.aspx?f=249081&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>Atlas Insurance and SOS Malta launch VR…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/MDB-hosts-20-European-institutions-to-discuss-the-challenges-of-digital-financing-6736268316">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl01_imgThumbnail" src="file.aspx?f=249080&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>MDB hosts 20 European institutions to…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/BOV-encourages-smarter-money-management-with-cash-migration-incentive-6736268315">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl02_imgThumbnail" src="file.aspx?f=249079&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>BOV encourages smarter money management…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/Maltese-Payroll-Software-Company-Buddy-kicks-off-Payroll-Growth-Summit-today-6736268311">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl03_imgThumbnail" src="file.aspx?f=249075&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>Maltese Payroll Software Company Buddy…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/HSBC-Malta-Foundation-supports-K-9-Urban-Search-and-Rescue-Malta-6736268309">
#  <div class="item-image-container">
#  <img alt="Representatives of the K-9 USAR Malta, a dedicated non-profit organisation committed to training highly specialised search and rescue dogs for disaster response" border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl04_imgThumbnail" src="file.aspx?f=249073&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>HSBC Malta Foundation supports K-9…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-04/business-news/New-shores-beckon-for-Boston-Multi-Family-Office-on-completion-of-acquisition-of-Aqua-Group-6736268308">
#  <div class="item-image-container">
#  <img alt="From left: Alex McNee, Sarah Mullins, Jo Luce" border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl05_imgThumbnail" src="file.aspx?f=249072&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>New shores beckon for Boston Multi…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-03-02/business-news/Trump-economics-Inflation-trends-and-pressures-on-European-commerce-6736268226">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl06_imgThumbnail" src="file.aspx?f=249025&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>Trump economics: Inflation trends and…</p>
#  </div>
#  </a>
#  </article>,
#  <article class="carousel-item">
#  <a href="/articles/2025-02-28/business-news/Fundacion-MAPFRE-supports-P-O-P-Up-project-in-collaboration-with-MFWS-6736268233">
#  <div class="item-image-container">
#  <img border="0" id="ctl00_CarouselArticles_TMI_rptCarousel_ctl07_imgThumbnail" src="file.aspx?f=249027&amp;width=160&amp;height=145"/>
#  </div>
#  <div class="item-title-container">
#  <p>Fundación MAPFRE supports P.O.P – Up'…</p>
#  </div>
#  </a>
#  </article>]

# %%
articles = []

filename = 'maltaindependentArticles.csv'

page_number = 1
max_pages = 315

while page_number <= max_pages:
    URL = 'https://www.independent.com.mt/business?pg=' + str(page_number)
    new_page = requests.get(URL)
    soup = BeautifulSoup(new_page.text, 'html')
    business_article = soup.find_all('article')
    
    for article in business_article:
        title = article.find('h4').get_text(strip=True) if article.find('h4') else None
        date = article.find('span').get_text(strip=True) if article.find('span') else None
        description = article.find('p').get_text(strip=True) if article.find('p') else None
        articles.append({'headline': title, 'date': date, 'description': description})
        
    dataset = pd.DataFrame(articles)
    dataset.to_csv(fr'C:\Users\ivane\Desktop\Dissertation\data\{filename}', index=False)    
    page_number += 1

# %%
df = pd.read_csv(fr'C:\Users\ivane\Desktop\Dissertation\data\{filename}')
df.head()
# Out:
#                                             headline  \
# 0  Atlas Insurance and SOS Malta launch VR educat...
# 1  MDB hosts 20 European institutions to discuss ...
# 2  BOV encourages smarter money management with c...
# 3  Maltese Payroll Software Company Buddy kicks o...
# 4  HSBC Malta Foundation supports K-9 Urban Searc...
#
#                            date  \
# 0  Tuesday, 4 March 2025, 12:26
# 1  Tuesday, 4 March 2025, 12:21
# 2  Tuesday, 4 March 2025, 11:29
# 3  Tuesday, 4 March 2025, 09:21
# 4  Tuesday, 4 March 2025, 09:16
#
#                                          description
# 0  Atlas Insurance and SOS Malta inaugurated thei...
# 1  The Malta Development Bank (MDB), in collabora...
# 2  Bank of Valletta is launching a Cash Migration...
# 3  Maltese technology leader Buddy is proud to an...
# 4  HSBC Malta Foundation is proud to support K-9 ...
