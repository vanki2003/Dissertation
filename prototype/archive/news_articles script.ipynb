# %%
import feedparser
import transformers
import requests
from transformers import pipeline
import warnings

warnings.filterwarnings('ignore')

ticker = 'AAPL'
keyword = 'apple'

pipe = pipeline(task='text-classification', model='ProsusAI/finbert')

rss_url = f'https://feeds.finance.yahoo.com/rss/2.0/headline?s={ticker}'
feed = feedparser.parse(rss_url)

# %%
total_score = 0
num_articles = 0

for i, entry in enumerate(feed.entries):
  if keyword.lower() not in entry.summary.lower():
    continue

  print(f'Tile: {entry.title}')
  print(f'Link: {entry.link}')
  print(f'Published: {entry.published}')
  print(f'Summary: {entry.summary}')

  sentiment = pipe(entry.summary)[0]

  print(f'Sentiment: {sentiment["label"]}, Score: {sentiment["score"]}')
  print('-' * 40)

  if sentiment['label'] == 'positive':
    total_score += sentiment['score']
    num_articles += 1
  elif sentiment['label'] == 'negative':
    total_score -= sentiment['score']
    num_articles += 1


final_score = total_score / num_articles
print(f'Overall sentiment {"Positive" if final_score >= 0.15 else "Negative" if final_score <= -0.15 else "Neutral"}')
# Out:
# Ttile: Is Apple Inc. (AAPL) the Best Kid-friendly Stock to Buy Right Now?
# Link: https://finance.yahoo.com/news/apple-inc-aapl-best-kid-175848382.html?.tsrc=rss
# Published: Sat, 28 Dec 2024 17:58:48 +0000
# Summary: We recently compiled a list of the 10 Best Kid-Friendly Stocks To Buy Right Now. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against the other kid-friendly stocks. Expert Thinks Value Stocks are Making a Comeback Investors and analysts alike are concerned about where equities are headed […]
# Sentiment: neutral, Score: 0.8044461011886597
# ----------------------------------------
# Ttile: Warren Buffett Sells Apple Stock and Buys a Restaurant Stock Up 3,100% Since Its IPO
# Link: https://www.fool.com/investing/2024/12/28/warren-buffett-sell-apple-stock-buy-stock-up-3100/?source=eptyholnk0000202&utm_source=yahoo-host-full&utm_medium=feed&utm_campaign=article&referring_guid=c6d2f02d-1e04-4267-b431-a2c4dcac250e&.tsrc=rss
# Published: Sat, 28 Dec 2024 08:30:00 +0000
# Summary: Warren Buffett reportedly manages about 90% of Berkshire Hathaway's (NYSE: BRK.A) (NYSE: BRK.B) equity securities portfolio, while understudies Todd Combs and Ted Weschler handle the rest.  The company does not disclose which investment manager makes each individual trade, but Buffett is almost certainly in charge of large positions like Apple (NASDAQ: AAPL).  Despite once calling Apple the "best business" in the world, Buffett sold 100 million shares in the third quarter, cutting Berkshire's stake by 25%.
# Sentiment: negative, Score: 0.9361082911491394
# ----------------------------------------
# Ttile: Analyst Says Apple (AAPL) Stock is Expensive Amid ‘Slow-Developing’ Upgrade Cycle
# Link: https://finance.yahoo.com/news/analyst-says-apple-aapl-stock-230821448.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 23:08:21 +0000
# Summary: We recently published a list of Analysts Are Talking About These 10 AI Stocks. In this article, we are going to take a look at where Apple Inc. (NASDAQ:AAPL) stands against other stocks analysts are talking about. Marco Argenti, Chief Information Officer at Goldman Sachs, recently said that in 2025, the world will witness the […]
# Sentiment: neutral, Score: 0.9047307968139648
# ----------------------------------------
# Ttile: Big Tech's legal battles: What to watch for in 2025
# Link: https://finance.yahoo.com/video/big-techs-legal-battles-watch-222030478.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 22:20:30 +0000
# Summary: The US government spent much of 2024 cracking down on tech giants like Google (GOOGL, GOOG), Apple (AAPL), and Meta (META). The efforts started under former President Trump and then carried over into President Biden’s administration. Yahoo Finance senior legal reporter Alexis Keenan appears on Market Domination to discuss key events, including the DOJ's victory in its antitrust case against Google and what to watch for in 2025 as Trump takes office again.  To watch more expert insights and analysis on the latest market action, check out more Market Domination Overtime here. This post was written by Josh Lynch
# Sentiment: neutral, Score: 0.9281449317932129
# ----------------------------------------
# Ttile: Magnificent Seven Stocks: Nvidia, Tesla Tumble; Apple, Google, Meta Sell Off
# Link: https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 21:18:42 +0000
# Summary: Dubbed the Magnificent Seven stocks, Apple, Microsoft, Google parent Alphabet, Amazon.com, Nvidia, Meta Platforms and Tesla lived up to their name in 2023 with big gains. And all of them boasted solid year-to-date gains in the final weeks of 2024.
# Sentiment: positive, Score: 0.8628824353218079
# ----------------------------------------
# Ttile: Dow Jones Stocks: Amazon, Apple Tumble; Nvidia Breaks Below Key Level
# Link: https://finance.yahoo.com/m/65b53896-faf4-3a06-9d0d-a63cf3c83192/dow-jones-stocks%3A-amazon%2C.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 19:01:33 +0000
# Summary: With the Dow Jones Industrial Average looking to end the year with solid gains, the best Dow Jones stocks to watch in December 2024 are Amazon.com, Apple, Nvidia, Salesforce and Walt Disney. There are clear winners — and losers — at the start of December.
# Sentiment: neutral, Score: 0.8459885716438293
# ----------------------------------------
# Ttile: Apple investors may want to brace for a sell-off
# Link: https://finance.yahoo.com/video/apple-investors-may-want-brace-183836401.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 18:38:36 +0000
# Summary: Apple (AAPL) shares are up about 8% over the past month. But BTIG chief market technician Jonathan Krinsky is warning investors about a potential sell-off in the stock. Krinsky notes that when Apple has posted five straight weeks of gains of more than 2%, the stock tends to fall over the following six weeks. Morning Brief Hosts Brad Smith and Brian Sozzi discuss the call in the video above. To watch more expert insights and analysis on the latest market action, check out more Morning Brief here. This post was written by Stephanie Mikulich.
# Sentiment: neutral, Score: 0.7002260088920593
# ----------------------------------------
# Ttile: 2024 Stock Market News: The Year At A Glance
# Link: https://finance.yahoo.com/m/57268148-4fbb-3f25-b6b3-8e584bdbac6c/2024-stock-market-news%3A-the.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 17:04:01 +0000
# Summary: Boosted by AI trends, Apple and other Mag 7 stocks notched all-time highs as the S&amp;P 500 and Nasdaq enjoyed record years.
# Sentiment: positive, Score: 0.9014374017715454
# ----------------------------------------
# Ttile: Mag 7 is turning to 'lag 7': How to play tech in 2025
# Link: https://finance.yahoo.com/video/mag-7-turning-lag-7-170000924.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 17:00:00 +0000
# Summary: Piper Sandler managing director and chief market technician Craig Johnson joins Josh Lipton on Market Domination. He suggests that, although stocks like Apple are trending upward, the "Magnificent Seven" — which comprises Nvidia (NVDA), Alphabet (GOOG, GOOGL), Tesla (TSLA), Microsoft (MSFT), Amazon (AMZN), Meta (META), and Apple (AAPL) — may become the "lag seven" in 2025 as "the relative performance has not been nearly as strong." Johnson shares his strategy for navigating the shifting tech landscape in the coming year. "I would rather see investors — and I suspect this will happen as you get into early 2025 — taking some, not all, but some of their profits out of those larger cap stocks, reducing those positions, and then again, recognizing some of those gains that they may not have wanted to recognize in 2024 and [shifting] down cap, looking at stocks like Twilio (TWLO)." He also highlights Robinhood (HOOD) as an opportunity for investors, given the "more friendly crypto policy from the new administration." Johnson advises viewers not to forget optical companies, like Coherent (COHR), which "could be a better place to put some money to work." To watch more expert insights and analysis on the latest market action, check out more Market Domination here. This post was written by Naomi Buchanan.
# Sentiment: neutral, Score: 0.8333327770233154
# ----------------------------------------
# Ttile: Apple's AI Strategy Could Send Its Stock to $325--Here's Why You Need to Pay Attention Now
# Link: https://finance.yahoo.com/news/apples-ai-strategy-could-send-165249253.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 16:52:49 +0000
# Summary: Wedbush analysts predict a "golden era" for Apple as AI-driven upgrades boost iPhone sales and services revenue.
# Sentiment: positive, Score: 0.939029335975647
# ----------------------------------------
# Ttile: Apple May be First to a $4 Trillion Market Cap. Will It Hold?
# Link: https://finance.yahoo.com/m/ef4cc110-10a7-3601-9f9a-a519d8dd17a1/apple-may-be-first-to-a-%244.html?.tsrc=rss
# Published: Fri, 27 Dec 2024 16:41:00 +0000
# Summary: Apple stock needs to close at or above $264.623 for the iphone maker to reach a $4 trillion market cap.
# Sentiment: positive, Score: 0.592346727848053
# ----------------------------------------
# Overall sentiment Positive
