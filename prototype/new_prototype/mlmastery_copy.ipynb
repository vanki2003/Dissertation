# %%
import pandas as pd
from datetime import datetime

# %%
# loading data
import os

pwd = os.getcwd()

dataset = pd.read_csv(pwd + '/merged_data.csv', index_col=0)
dataset.head()
# Out:
#                Open     Close    Change  majority_sentiment  average_sentiment
# date
# 2025-02-28  3913.54  3915.439  0.048601                   2           0.890644
# 2025-02-27  3908.73  3913.537  0.122904                   2           0.954200
# 2025-02-26  3910.01  3908.733 -0.032736                   0           0.812788
# 2025-02-25  3920.37  3910.013 -0.264057                   2           0.835742
# 2025-02-24  3883.52  3920.365  0.948727                   2           0.809047

# %%
from matplotlib import pyplot
import matplotlib.pyplot as plt

values = dataset.values

# specify columns to plot
groups = [0, 1, 2, 4]
i = 1

# plot each column
pyplot.figure()

for group in groups:
    pyplot.subplot(len(groups), 1, i)
    pyplot.plot(values[:, group])
    pyplot.title(dataset.columns[group], y=0.5, loc='center')
    i += 1
pyplot.show()

# %% [markdown]
# # LSTM Prep and Implementation
#
# The first step is to prepare the pollution dataset for the LSTM.
#
# This involves framing the dataset as a supervised learning problem and normalizing the input variables.
#
# We will frame the supervised learning problem as predicting the pollution at the current hour (t) given the pollution measurement and weather conditions at the prior time step.

# %%
# prepare data for lstm
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# load dataset
dataset = pd.read_csv(pwd + '/merged_data.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
# encoder = LabelEncoder()
# values[:,3] = encoder.fit_transform(values[:,3])
# ensure all data is float
values = values.astype('float32')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
print(reframed.columns)
# Out:
# Index(['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)',
#        'var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)'],
#       dtype='object')

# %%
reframed.drop(reframed.columns[[5,7,8,9]], axis=1, inplace=True)  # drop all except var2(t) (Close price)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var2(t)
# 1   0.317778   0.319074   0.384768        1.0   0.850623  0.317775
# 2   0.314492   0.317775   0.392624        1.0   0.964518  0.314494
# 3   0.315367   0.314494   0.376168        0.0   0.711102  0.315368
# 4   0.322442   0.315368   0.351712        1.0   0.752235  0.322438
# 5   0.297275   0.322438   0.479934        1.0   0.704397  0.297275

# %%
values = reframed.values
n_train = int(len(values) * 0.8)
train = values[:n_train, :]
test = values[n_train:, :]

train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (800, 1, 5) (800,) (200, 1, 5) (200,)

# %%
n_samples = train_X.shape[0]
n_features = train_X.shape[2]

print(n_samples)
print(n_features)
# Out:
# 800
# 5

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from sklearn.preprocessing import MinMaxScaler

model = Sequential()

# 1D Convolutional Layer
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(1, n_features)))

model.add(MaxPooling1D(pool_size=1))

# LSTM Layers
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

model.summary()

history = model.fit(train_X, train_y, 
                    epochs=100, 
                    batch_size=32, 
                    validation_data=(test_X, test_y), 
                    verbose=2, 
                    shuffle=False)

# Predictions
yhat = model.predict(test_X)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 64)             384
#
#  max_pooling1d (MaxPooling1  (None, 1, 64)             0
#  D)
#
#  lstm (LSTM)                 (None, 1, 50)             23000
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 43635 (170.45 KB)
# Trainable params: 43635 (170.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 25/25 - 3s - loss: 0.0367 - val_loss: 0.3474 - 3s/epoch - 139ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 0.0294 - val_loss: 0.3751 - 93ms/epoch - 4ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 0.0193 - val_loss: 0.2912 - 89ms/epoch - 4ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 0.0172 - val_loss: 0.2263 - 91ms/epoch - 4ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 0.0112 - val_loss: 0.1205 - 87ms/epoch - 3ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 0.0050 - val_loss: 0.0214 - 93ms/epoch - 4ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.0015 - val_loss: 0.0032 - 89ms/epoch - 4ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 4.5672e-04 - val_loss: 0.0016 - 90ms/epoch - 4ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 3.9201e-04 - val_loss: 6.2711e-04 - 91ms/epoch - 4ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 3.0059e-04 - val_loss: 7.7922e-04 - 92ms/epoch - 4ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 2.7320e-04 - val_loss: 5.8922e-04 - 95ms/epoch - 4ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 2.4626e-04 - val_loss: 5.7370e-04 - 91ms/epoch - 4ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 2.3259e-04 - val_loss: 5.0121e-04 - 87ms/epoch - 3ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 2.1837e-04 - val_loss: 4.7209e-04 - 90ms/epoch - 4ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 2.1016e-04 - val_loss: 4.2908e-04 - 87ms/epoch - 3ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 2.0288e-04 - val_loss: 4.0313e-04 - 109ms/epoch - 4ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 1.9844e-04 - val_loss: 3.7701e-04 - 88ms/epoch - 4ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 1.9468e-04 - val_loss: 3.5642e-04 - 90ms/epoch - 4ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 1.9137e-04 - val_loss: 3.3580e-04 - 88ms/epoch - 4ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 1.8761e-04 - val_loss: 3.1292e-04 - 90ms/epoch - 4ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 1.8516e-04 - val_loss: 2.8218e-04 - 88ms/epoch - 4ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 1.8067e-04 - val_loss: 2.4281e-04 - 90ms/epoch - 4ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 1.7871e-04 - val_loss: 2.0999e-04 - 88ms/epoch - 4ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 1.7452e-04 - val_loss: 1.9682e-04 - 85ms/epoch - 3ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 1.7869e-04 - val_loss: 1.9583e-04 - 85ms/epoch - 3ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 1.7866e-04 - val_loss: 1.9008e-04 - 85ms/epoch - 3ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 2.0182e-04 - val_loss: 2.7625e-04 - 87ms/epoch - 3ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 1.9810e-04 - val_loss: 1.9480e-04 - 88ms/epoch - 4ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 2.1277e-04 - val_loss: 2.4036e-04 - 91ms/epoch - 4ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 1.9140e-04 - val_loss: 1.7069e-04 - 87ms/epoch - 3ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 1.9692e-04 - val_loss: 1.8666e-04 - 88ms/epoch - 4ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 1.7867e-04 - val_loss: 1.4249e-04 - 87ms/epoch - 3ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 1.8176e-04 - val_loss: 1.6020e-04 - 88ms/epoch - 4ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 1.7203e-04 - val_loss: 1.3511e-04 - 89ms/epoch - 4ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 1.7378e-04 - val_loss: 1.3909e-04 - 87ms/epoch - 3ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 1.6996e-04 - val_loss: 1.2663e-04 - 85ms/epoch - 3ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 1.7285e-04 - val_loss: 1.4228e-04 - 87ms/epoch - 3ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 1.7551e-04 - val_loss: 1.3368e-04 - 86ms/epoch - 3ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 1.8309e-04 - val_loss: 1.6506e-04 - 86ms/epoch - 3ms/step
# Epoch 40/100
# 25/25 - 0s - loss: 1.9419e-04 - val_loss: 1.5278e-04 - 86ms/epoch - 3ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 2.0944e-04 - val_loss: 2.2113e-04 - 92ms/epoch - 4ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 2.2688e-04 - val_loss: 1.8449e-04 - 96ms/epoch - 4ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 2.3836e-04 - val_loss: 2.7575e-04 - 85ms/epoch - 3ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 2.4770e-04 - val_loss: 2.1109e-04 - 87ms/epoch - 3ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 2.4955e-04 - val_loss: 2.8678e-04 - 87ms/epoch - 3ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 2.4240e-04 - val_loss: 2.1788e-04 - 86ms/epoch - 3ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 2.3790e-04 - val_loss: 2.4367e-04 - 87ms/epoch - 3ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 2.2146e-04 - val_loss: 1.9601e-04 - 85ms/epoch - 3ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 2.2490e-04 - val_loss: 2.2422e-04 - 87ms/epoch - 3ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 2.1723e-04 - val_loss: 1.8836e-04 - 86ms/epoch - 3ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 2.2837e-04 - val_loss: 2.3534e-04 - 86ms/epoch - 3ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 2.3309e-04 - val_loss: 1.9898e-04 - 86ms/epoch - 3ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 2.5512e-04 - val_loss: 2.9107e-04 - 86ms/epoch - 3ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 2.7020e-04 - val_loss: 2.2923e-04 - 87ms/epoch - 3ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 2.9621e-04 - val_loss: 3.7617e-04 - 85ms/epoch - 3ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 3.1094e-04 - val_loss: 2.6028e-04 - 86ms/epoch - 3ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 3.2163e-04 - val_loss: 4.0136e-04 - 86ms/epoch - 3ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 3.1458e-04 - val_loss: 2.4914e-04 - 85ms/epoch - 3ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 3.0472e-04 - val_loss: 3.4378e-04 - 86ms/epoch - 3ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 2.7313e-04 - val_loss: 2.0695e-04 - 85ms/epoch - 3ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 2.6496e-04 - val_loss: 2.7311e-04 - 94ms/epoch - 4ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 2.3115e-04 - val_loss: 1.7181e-04 - 84ms/epoch - 3ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 2.3483e-04 - val_loss: 2.3531e-04 - 86ms/epoch - 3ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 2.1725e-04 - val_loss: 1.5936e-04 - 86ms/epoch - 3ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 2.2828e-04 - val_loss: 2.3171e-04 - 107ms/epoch - 4ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 2.2666e-04 - val_loss: 1.6303e-04 - 86ms/epoch - 3ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 2.4870e-04 - val_loss: 2.7154e-04 - 87ms/epoch - 3ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 2.6009e-04 - val_loss: 1.8421e-04 - 85ms/epoch - 3ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 2.9350e-04 - val_loss: 3.5174e-04 - 87ms/epoch - 3ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 3.1224e-04 - val_loss: 2.1643e-04 - 86ms/epoch - 3ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 3.4082e-04 - val_loss: 4.2799e-04 - 87ms/epoch - 3ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 3.4283e-04 - val_loss: 2.2954e-04 - 89ms/epoch - 4ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 3.3805e-04 - val_loss: 3.9579e-04 - 87ms/epoch - 3ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 3.0476e-04 - val_loss: 1.9444e-04 - 87ms/epoch - 3ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 2.8812e-04 - val_loss: 3.0139e-04 - 83ms/epoch - 3ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 2.4313e-04 - val_loss: 1.5177e-04 - 85ms/epoch - 3ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 2.4245e-04 - val_loss: 2.3867e-04 - 85ms/epoch - 3ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 2.1405e-04 - val_loss: 1.3183e-04 - 86ms/epoch - 3ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 2.2197e-04 - val_loss: 2.1815e-04 - 84ms/epoch - 3ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 2.1429e-04 - val_loss: 1.2949e-04 - 84ms/epoch - 3ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 2.2806e-04 - val_loss: 2.3131e-04 - 84ms/epoch - 3ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 2.3558e-04 - val_loss: 1.3992e-04 - 86ms/epoch - 3ms/step
# Epoch 83/100
# 25/25 - 0s - loss: 2.6227e-04 - val_loss: 2.9253e-04 - 83ms/epoch - 3ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 2.8554e-04 - val_loss: 1.6742e-04 - 84ms/epoch - 3ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 3.2424e-04 - val_loss: 3.9565e-04 - 83ms/epoch - 3ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 3.5096e-04 - val_loss: 2.0520e-04 - 84ms/epoch - 3ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 3.6506e-04 - val_loss: 4.4853e-04 - 82ms/epoch - 3ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 3.5728e-04 - val_loss: 2.0128e-04 - 83ms/epoch - 3ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 3.2843e-04 - val_loss: 3.5905e-04 - 82ms/epoch - 3ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 2.7970e-04 - val_loss: 1.4893e-04 - 82ms/epoch - 3ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 2.6459e-04 - val_loss: 2.5740e-04 - 85ms/epoch - 3ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 2.2017e-04 - val_loss: 1.1527e-04 - 84ms/epoch - 3ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 2.2132e-04 - val_loss: 2.0712e-04 - 82ms/epoch - 3ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 2.0351e-04 - val_loss: 1.0612e-04 - 85ms/epoch - 3ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 2.1099e-04 - val_loss: 1.9685e-04 - 86ms/epoch - 3ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 2.1147e-04 - val_loss: 1.0831e-04 - 92ms/epoch - 4ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 2.2787e-04 - val_loss: 2.2138e-04 - 82ms/epoch - 3ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 2.4341e-04 - val_loss: 1.2261e-04 - 83ms/epoch - 3ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 2.7420e-04 - val_loss: 2.9095e-04 - 83ms/epoch - 3ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 3.0515e-04 - val_loss: 1.5466e-04 - 92ms/epoch - 4ms/step
# 7/7 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(test_y, yhat)
mse = mean_squared_error(test_y, yhat)
rmse = np.sqrt(mse)
r2 = r2_score(test_y, yhat)
loss = model.evaluate(test_X, test_y)

print(f'Test Loss: {loss}')
print(f'Mean Absolute Error: {mae}')
print(f'R-squared Score: {r2}')

plt.figure(figsize=(10, 6))
plt.plot(test_y, label='Actual')
plt.plot(yhat, label='Predicted')
plt.title(f'Actual vs Predicted Values\nR² = {r2:.2f}, RMSE = {rmse:.2f}')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5466e-04
# Test Loss: 0.00015466089826077223
# Mean Absolute Error: 0.010221028700470924
# R-squared Score: 0.9564337134361267

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt

# Assuming train_X and train_y are already defined
tscv = TimeSeriesSplit(n_splits=5)
mae_scores = []

for train_index, test_index in tscv.split(train_X):
    X_train, X_test = train_X[train_index], train_X[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]

    model = Sequential()
    model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')

    history = model.fit(X_train, y_train, epochs=50, batch_size=72, validation_data=(X_test, y_test), verbose=2, shuffle=False)

    y_pred = model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mae_scores.append(mae)

    # Plot history
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='test')
    plt.legend()
    plt.show()

print(f'Mean MAE: {np.mean(mae_scores)}')
print(f'Standard Deviation of MAE: {np.std(mae_scores)}')

# %%
# design network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM


model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))

model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()

pyplot.show()

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten
from sklearn.preprocessing import MinMaxScaler

# Ensure train_X has enough timesteps for Conv1D
timesteps = 1  # Set to at least 3 to match kernel_size
features = train_X.shape[1] * train_X.shape[2] // timesteps

# Reshape input for CNN-LSTM
train_X = train_X.reshape((n_samples, 1, n_features))
test_X = test_X.reshape((n_samples, 1, n_features))

# Define CNN-LSTM model
model = Sequential()

# 1D Convolutional Layer
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(timesteps, features)))

# MaxPooling Layer
model.add(MaxPooling1D(pool_size=1))

# LSTM Layers
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))

# Fully Connected Dense Layer
model.add(Dense(1))

# Compile Model
model.compile(optimizer='adam', loss='mse')

# Model Summary
model.summary()

# Train the CNN-LSTM Model
history = model.fit(train_X, train_y, 
                    epochs=50, 
                    batch_size=72, 
                    validation_data=(test_X, test_y), 
                    verbose=2, 
                    shuffle=False)

# Predictions
yhat = model.predict(test_X)
